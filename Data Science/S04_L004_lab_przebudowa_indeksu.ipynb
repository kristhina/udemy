# %%
import pandas as pd
import numpy as np

# %%
fortune = pd.read_csv('dane/course-files/Fortune_500_2017.csv')
fortune.head()
# Out:
#    Rank               Title                           Website  Employees  \
# 0     1             Walmart            http://www.walmart.com    2300000
# 1     2  Berkshire Hathaway  http://www.berkshirehathaway.com     367700
# 2     3               Apple              http://www.apple.com     116000
# 3     4         Exxon Mobil         http://www.exxonmobil.com      72700
# 4     5            McKesson           http://www.mckesson.com      68000
#
#         Sector                                  Industry         Hqlocation  \
# 0    Retailing                     General Merchandisers    Bentonville, AR
# 1   Financials  Insurance: Property and Casualty (Stock)          Omaha, NE
# 2   Technology               Computers, Office Equipment      Cupertino, CA
# 3       Energy                        Petroleum Refining         Irving, TX
# 4  Wholesalers                  Wholesalers: Health Care  San Francisco, CA
#
#                    Hqaddr         Hqcity Hqstate  ...  \
# ...

# %%
fortune.set_index('Rank', inplace = True)
fortune.head()
# Out:
#                    Title                           Website  Employees  \
# Rank
# 1                Walmart            http://www.walmart.com    2300000
# 2     Berkshire Hathaway  http://www.berkshirehathaway.com     367700
# 3                  Apple              http://www.apple.com     116000
# 4            Exxon Mobil         http://www.exxonmobil.com      72700
# 5               McKesson           http://www.mckesson.com      68000
#
#            Sector                                  Industry  \
# Rank
# 1       Retailing                     General Merchandisers
# 2      Financials  Insurance: Property and Casualty (Stock)
# 3      Technology               Computers, Office Equipment
# 4          Energy                        Petroleum Refining
# 5     Wholesalers                  Wholesalers: Health Care
#
#              Hqlocation                  Hqaddr         Hqcity Hqstate  Hqzip  \
# Rank
# 1       Bentonville, AR     702 S.W. Eighth St.    Bentonville      AR  72716
# ...

# %%
fortune.loc[100:105]
# Out:
#                             Title                    Website  Employees  \
# Rank
# 100         Capital One Financial  http://www.capitalone.com      47300
# 101      Twenty-First Century Fox        http://www.21cf.com      21500
# 102                          USAA        http://www.usaa.com      29943
# 103           World Fuel Services     http://www.wfscorp.com       5000
# 104   Philip Morris International         http://www.pmi.com      79500
# 105                         Deere   http://www.johndeere.com      56767
#
#                          Sector                                  Industry  \
# Rank
# 100                  Financials                          Commercial Banks
# 101                       Media                             Entertainment
# 102                  Financials  Insurance: Property and Casualty (Stock)
# 103                      Energy                                    Energy
# 104   Food, Beverages & Tobacco                                   Tobacco
# ...

# %%
fortune.loc[100:105][['Title', 'Employees']]
# Out:
#                             Title  Employees
# Rank
# 100         Capital One Financial      47300
# 101      Twenty-First Century Fox      21500
# 102                          USAA      29943
# 103           World Fuel Services       5000
# 104   Philip Morris International      79500
# 105                         Deere      56767

# %%
fortune.reset_index(inplace=True)

# %%
fortune.set_index('Title', inplace=True)
fortune.head()
# Out:
#                     Rank                           Website  Employees  \
# Title
# Walmart                1            http://www.walmart.com    2300000
# Berkshire Hathaway     2  http://www.berkshirehathaway.com     367700
# Apple                  3              http://www.apple.com     116000
# Exxon Mobil            4         http://www.exxonmobil.com      72700
# McKesson               5           http://www.mckesson.com      68000
#
#                          Sector                                  Industry  \
# Title
# Walmart               Retailing                     General Merchandisers
# Berkshire Hathaway   Financials  Insurance: Property and Casualty (Stock)
# Apple                Technology               Computers, Office Equipment
# Exxon Mobil              Energy                        Petroleum Refining
# McKesson            Wholesalers                  Wholesalers: Health Care
#
#                            Hqlocation                  Hqaddr         Hqcity  \
# ...

# %%
fortune.sort_index(inplace=True)
fortune.head()
# Out:
#                         Rank               Website  Employees  \
# Title
# 3M                        94     http://www.3m.com      91584
# A-Mark Precious Metals   395  http://www.amark.com         83
# ABM Industries           500    http://www.abm.com     110000
# ADP                      240    http://www.adp.com      57000
# AECOM                    161  http://www.aecom.com      87000
#
#                                             Sector  \
# Title
# 3M                                     Industrials
# A-Mark Precious Metals                   Materials
# ABM Industries                   Business Services
# ADP                              Business Services
# AECOM                   Engineering & Construction
#
#                                                 Industry        Hqlocation  \
# Title
# 3M                                         Miscellaneous      St. Paul, MN
# A-Mark Precious Metals                     Miscellaneous  Santa Monica, CA
# ...

# %%
fortune.loc['X':'Y']
# Out:
#                Rank                    Website  Employees          Sector  \
# Title
# XPO Logistics   191         http://www.xpo.com      87000  Transportation
# Xcel Energy     256  http://www.xcelenergy.com      11476          Energy
# Xerox           162       http://www.xerox.com     133600      Technology
#
#                                    Industry       Hqlocation  \
# Title
# XPO Logistics  Transportation and Logistics    Greenwich, CT
# Xcel Energy     Utilities: Gas and Electric  Minneapolis, MN
# Xerox                  Computer Peripherals      Norwalk, CT
#
#                           Hqaddr       Hqcity Hqstate  Hqzip  ...  \
# Title                                                         ...
# XPO Logistics    5 American Lane    Greenwich      CT   6831  ...
# Xcel Energy    414 Nicollet Mall  Minneapolis      MN  55401  ...
# Xerox             45 Glover Ave.      Norwalk      CT   6850  ...
#
#                                                    Ceo-title  \
# ...
